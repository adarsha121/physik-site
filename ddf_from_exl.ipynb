# %% [markdown]
# ### Dirac Delta simulation from excel files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the excel file 

# df = pd.read_excel('Dirac_Delta_Simulation_Dynamic.xlsx') -> this loads the first sheet by default only

# to load the entire excel workbook
exl_file = pd.ExcelFile('Dirac_Delta_Simulation_Dynamic.xlsx')
print(exl_file.sheet_names) # to see the sheet names in the workbook
# Out:
# ['Dashboard', 'Point Convergence', 'Spatial DDF', 'Integration']

# %% [markdown]
# ### Basic info of the excel files like sheets and all

# %%
sheet1 = pd.read_excel(exl_file, sheet_name=exl_file.sheet_names[0])
sheet2 = pd.read_excel(exl_file, sheet_name=exl_file.sheet_names[1])
sheet3 = pd.read_excel(exl_file, sheet_name=exl_file.sheet_names[2])
sheet4 = pd.read_excel(exl_file, sheet_name=exl_file.sheet_names[3])
print(sheet2.head())
# Out:
#    k  Term (x=x')  CumSum (x=x')  Unnamed: 3  Term (x=x_far)  CumSum (x=x_far)
# 0  1          NaN            NaN         NaN             NaN               NaN
# 1  2          NaN            NaN         NaN             NaN               NaN
# 2  3          NaN            NaN         NaN             NaN               NaN
# 3  4          NaN            NaN         NaN             NaN               NaN
# 4  5          NaN            NaN         NaN             NaN               NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sheet1_df = exl_file.parse(sheet2) # to load the data from sheet1 into a dataframe
#       2 print(sheet1_df.head())
#
# File ~/Documents/for_codeing/prac_msc/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:1780, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1630 def parse(
#    1631     self,
#    1632     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1649     **kwds,
#    1650 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1651     """
#    1652     Parse specified sheet(s) into a DataFrame.
#    1653
#    (...)   1778     >>> file.parse()  # doctest: +SKIP
# ...
